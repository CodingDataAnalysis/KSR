# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

driver_path = 'C:/Users/s_liouxe/Desktop/home-data-for-ml-course/'
train = pd.read_csv(driver_path + 'train.csv')
test = pd.read_csv(driver_path + 'test.csv')
submission = pd.read_csv(driver_path + 'sample_submission.csv')

# %%
train.shape, test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
# columns 개수 달라서 두 데이터 비교

train_lst = train.columns.to_list()
test_lst = test.columns.to_list()

print(set(train_lst) - set(test_lst))
print(set(test_lst) - set(train_lst))

# 가격 test의 경우 가격 columns 만 추가됨
# Out:
# {'SalePrice'}
# set()

# %%
# 결측치 n건 이하 column 삭제

column_cnt = []
for i in train_lst:
    if train[i].isnull().sum(axis=0) != 0:
        column_cnt.append(i)
        
print(column_cnt)
print(len(column_cnt))
# Out:
# ['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']
# 19

# %%
# 결측치 n건 이하 column 삭제

column_cnt2 = []
for i in test_lst:
    if test[i].isnull().sum(axis=0) != 0:
        column_cnt2.append(i)
        
print(column_cnt2)
print(len(column_cnt2))
# Out:
# ['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType']
# 33

# %%
# print(set(column_cnt) - set(column_cnt2))
# print(set(column_cnt2) - set(column_cnt))

new_cnt = list(set(column_cnt + column_cnt2))
new_cnt2 = list(set(train_lst) - set(new_cnt))

# %%
train_n = train.drop(new_cnt, axis=1)
test_n = test.drop(new_cnt, axis=1)

# %%
train_n
# Out:
#         Id  MSSubClass  LotArea Street LotShape LandContour LotConfig  \
# 0        1          60     8450   Pave      Reg         Lvl    Inside
# 1        2          20     9600   Pave      Reg         Lvl       FR2
# 2        3          60    11250   Pave      IR1         Lvl    Inside
# 3        4          70     9550   Pave      IR1         Lvl    Corner
# 4        5          60    14260   Pave      IR1         Lvl       FR2
# ...    ...         ...      ...    ...      ...         ...       ...
# 1455  1456          60     7917   Pave      Reg         Lvl    Inside
# 1456  1457          20    13175   Pave      Reg         Lvl    Inside
# 1457  1458          70     9042   Pave      Reg         Lvl    Inside
# 1458  1459          20     9717   Pave      Reg         Lvl    Inside
# 1459  1460          20     9937   Pave      Reg         Lvl    Inside
#
#      LandSlope Neighborhood Condition1  ... OpenPorchSF EnclosedPorch  \
# ...

# %%
for i in new_cnt2:
    print("===== {} =====".format(i))
    print(train_n[i].value_counts())
# Out:
# ===== PoolArea =====
# 0      1453
# 480       1
# 512       1
# 519       1
# 555       1
# 576       1
# 648       1
# 738       1
# Name: PoolArea, dtype: int64
# ===== ExterCond =====
# TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64
# ===== YearBuilt =====
# 2006    67
# 2005    64
# 2004    54
# 2007    49
# 2003    45
#         ..
# 1904     1
# 1898     1
# 1893     1
# 1882     1
# 2010     1
# Name: YearBuilt, Length: 112, dtype: int64
# ===== HouseStyle =====
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64
# ===== LandSlope =====
# Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64
# ===== YearRemodAdd =====
# 1950    178
# 2006     97
# 2007     76
# 2005     73
# 2004     62
#        ...
# 2010      6
# 1983      5
# 1986      5
# 1952      5
# 1951      4
# ...

# %%
train_n2 = train_n.drop(['3SsnPorch', 'LowQualFinSF', 'PoolArea', 'Street','Condition2'], axis=1)
train_n2
# Out:
#         Id  MSSubClass  LotArea LotShape LandContour LotConfig LandSlope  \
# 0        1          60     8450      Reg         Lvl    Inside       Gtl
# 1        2          20     9600      Reg         Lvl       FR2       Gtl
# 2        3          60    11250      IR1         Lvl    Inside       Gtl
# 3        4          70     9550      IR1         Lvl    Corner       Gtl
# 4        5          60    14260      IR1         Lvl       FR2       Gtl
# ...    ...         ...      ...      ...         ...       ...       ...
# 1455  1456          60     7917      Reg         Lvl    Inside       Gtl
# 1456  1457          20    13175      Reg         Lvl    Inside       Gtl
# 1457  1458          70     9042      Reg         Lvl    Inside       Gtl
# 1458  1459          20     9717      Reg         Lvl    Inside       Gtl
# 1459  1460          20     9937      Reg         Lvl    Inside       Gtl
#
#      Neighborhood Condition1 BldgType  ... PavedDrive  WoodDeckSF  \
# ...

# %%
text_lst = []

for i in train_n2:
    if train_n2[i].dtype != 'int64':
        text_lst.append(i)
        
train_n3 = train_n2.drop(text_lst, axis = 1)
train_n3
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  1stFlrSF  2ndFlrSF  GrLivArea  ...  TotRmsAbvGrd  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corrMat = train_n3.corr()
y_corr = corrMat['SalePrice']

y_corr = pd.DataFrame(y_corr)
y_corr.rename(columns={'SalePrice':'yCorr'}, inplace=True)

# %%
y_corr
# Out:
#                   yCorr
# Id            -0.021917
# MSSubClass    -0.084284
# LotArea        0.263843
# OverallQual    0.790982
# OverallCond   -0.077856
# YearBuilt      0.522897
# YearRemodAdd   0.507101
# 1stFlrSF       0.605852
# 2ndFlrSF       0.319334
# GrLivArea      0.708624
# FullBath       0.560664
# HalfBath       0.284108
# BedroomAbvGr   0.168213
# KitchenAbvGr  -0.135907
# TotRmsAbvGrd   0.533723
# Fireplaces     0.466929
# WoodDeckSF     0.324413
# OpenPorchSF    0.315856
# EnclosedPorch -0.128578
# ScreenPorch    0.111447
# MiscVal       -0.021190
# MoSold         0.046432
# YrSold        -0.028923
# SalePrice      1.000000

# %%
y_corr[y_corr['yCorr'] > abs(0.3)]
# Out:
#                  yCorr
# OverallQual   0.790982
# YearBuilt     0.522897
# YearRemodAdd  0.507101
# 1stFlrSF      0.605852
# 2ndFlrSF      0.319334
# GrLivArea     0.708624
# FullBath      0.560664
# TotRmsAbvGrd  0.533723
# Fireplaces    0.466929
# WoodDeckSF    0.324413
# OpenPorchSF   0.315856
# SalePrice     1.000000

# %%
final_value_train = list(y_corr[y_corr['yCorr'] > abs(0.3)].index) + ['Id']
final_value_test = list(y_corr[y_corr['yCorr'] > abs(0.3)].index) + ['Id']
final_value_test.remove('SalePrice')
final_value_test.remove('Id')
final_value_train.remove('Id')

final_value_test
final_value_train
# Out:
# ['OverallQual',
#  'YearBuilt',
#  'YearRemodAdd',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'SalePrice']

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
train_n4 = train_n3[final_value_train]
test_n4 = test[final_value_test]

X_train = train_n4.drop(['SalePrice'], axis=1)
y_train = train_n4['SalePrice']

X_test = test_n4.drop(['SalePrice'], axis=1)
y_test = test_n4['SalePrice'] 

test_n4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [57], in <cell line: 2>()
#       1 train_n4 = train_n3[final_value_train]
# ----> 2 test_n4 = test[final_value_test]
#       5 # X_train = train_n4.drop(['SalePrice'], axis=1)
#       6 # y_train = train_n4['SalePrice']
#       7
#       8 # X_test = test_n4.drop(['SalePrice'], axis=1)
#       9 # y_test = test_n4['SalePrice']
#      11 test_n4
#
# File ~\Anaconda3\lib\site-packages\pandas\core\frame.py:3030, in DataFrame.__getitem__(self, key)
#    3028     if is_iterator(key):
#    3029         key = list(key)
# -> 3030     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3032 # take() does not accept boolean indexers
#    3033 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(train_n4, y_train, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(train_n4, y_train, random_state=0)
#
# NameError: name 'y_train' is not defined

# %%
reg = LinearRegression().fit(X_train, y)
print(reg.predict(X_train))
# Out:
# [208245.17828575 177968.5560973  220201.01976708 ... 241724.56160462
#  135393.14161165 161736.30730837]

# %%
preds = linear_reg_model.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 preds = linear_reg_model.predict(X_train)
#
# File ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:367, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
# --> 367     check_is_fitted(self)
#     369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
print(f'RMSLE, {rmsle(y, preds, True):4f}')
